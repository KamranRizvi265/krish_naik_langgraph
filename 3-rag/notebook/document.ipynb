# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={
        "source": "example_source", 
        "pages" : 10,
        "author": "John Doe",
        "date_created": "2023-01-01"
        }
)
doc
# Out:
# Document(metadata={'source': 'example_source', 'pages': 10, 'author': 'John Doe', 'date_created': '2023-01-01'}, page_content='This is the content of the document.')

# %%
# Create text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt": """Python Introduction
    Python is a high-level, interpreted programming language known for its simplicity and readability. 
    It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.
    
    Key Features:
    - Easy to learn and use
    - Extensive standard library
    - Cross-platform compatibility

    Python is widely used in web development, data analysis, artificial intelligence, scientific computing, and more.""",

    "../data/text_files/ml_intro.txt": """Machine Learning Introduction
    Machine Learning is the subset of artificial intelligence that focuses on building systems that can learn from and make decisions based on data.

    Types of Machine Learning:
    1. Supervised Learning: The model is trained on labeled data
    2. Unsupervised Learning: The model finds patterns in unlabeled data
    3. Reinforcement Learning: The model learns by interacting with an environment and receiving feedback
    """
}

for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %% [markdown]
# #### Text Loader

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Introduction\n    Python is a high-level, interpreted programming language known for its simplicity and readability. \n    It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.\n\n    Key Features:\n    - Easy to learn and use\n    - Extensive standard library\n    - Cross-platform compatibility\n\n    Python is widely used in web development, data analysis, artificial intelligence, scientific computing, and more.')]

# %%
print(document[0].page_content)
# Out:
# Python Introduction
#     Python is a high-level, interpreted programming language known for its simplicity and readability.
#     It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.
#
#     Key Features:
#     - Easy to learn and use
#     - Extensive standard library
#     - Cross-platform compatibility
#
#     Python is widely used in web development, data analysis, artificial intelligence, scientific computing, and more.

# %% [markdown]
# #### Directory Loader

# %%
from langchain_community.document_loaders import DirectoryLoader

# Load all text files in the directory
directory_loader = DirectoryLoader(
    "../data/text_files", 
    glob="**/*.txt", # pattern to match all text files in the directory and subdirectories
    loader_cls=TextLoader, # loader class to use for loading the files
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)

documents = directory_loader.load()
print(f"Loaded {len(documents)} documents from the directory.")
# Out:
# Loaded 2 documents from the directory.

# %%
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\ml_intro.txt'}, page_content='Machine Learning Introduction\n    Machine Learning is the subset of artificial intelligence that focuses on building systems that can learn from and make decisions based on data.\n\n    Types of Machine Learning:\n    1. Supervised Learning: The model is trained on labeled data\n    2. Unsupervised Learning: The model finds patterns in unlabeled data\n    3. Reinforcement Learning: The model learns by interacting with an environment and receiving feedback\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Introduction\n    Python is a high-level, interpreted programming language known for its simplicity and readability. \n    It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.\n\n    Key Features:\n    - Easy to learn and use\n    - Extensive standard library\n    - Cross-platform compatibility\n\n    Python is widely used in web development, data analysis, artificial intelligence, scientific computing, and more.')]

# %% [markdown]
# #### PDF Loader

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# Load PDF files using PyPDFLoader
directory_loader = DirectoryLoader(
    "../data/pdf_files", 
    glob="**/*.pdf", # pattern to match all PDF files in the directory and subdirectories
    loader_cls=PyMuPDFLoader, # loader class to use for loading the files
    show_progress=False
)

documents = directory_loader.load()
print(f"Loaded {len(documents)} PDF documents from the directory.")
# Out:
# Loaded 19 PDF documents from the directory.

# %%
documents
# Out:
# [Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='The AI Revolution: Unlocking\nBusiness Value and Strategic\nAdvantage\nA Comprehensive Analysis of Artificial Intelligence Trends, Opportunities, and\nChallenges\nPREPARED BY:\n InsightSwarm Intelligence Agent\nDATE OF ISSUE:\n August 2026'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Table of Contents\nMARKET SIZE\n145.2B\n+12.4% CAGR\n(2020-2026)\nADOPTION RATE\n78%\nAcross Fortune 500\nCompanies\nFUNDING LEVEL\n18.4B\nTotal Venture Capital\nInflow\nENTERPRISE USERS\n4.2M\nActive Deployments\nglobally\n...........................................................\n1. Introduction & Context\n...........................................................\n2. Market Landscape & Analysis\n...........................................................\n3. Structured Comparison Table\n...........................................................\n4. Case Studies\n...........................................................\n5. Best Practices & Tactical Recommendations\n...........................................................\n6. Future Trends & Strategic Outlook\n...........................................................\n7. Conclusion & Strategic Summary\n...........................................................\nReferences\nInsightSwarm Agent Ecosystem\nPage 2 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content='1. Introduction & Context\nArtificial Intelligence (AI) has become a transformative force in the business world, driving\ninnovation, efficiency, and growth. As AI continues to evolve, organizations are increasingly seeking\nto harness its potential to gain a strategic advantage. This report provides a comprehensive analysis\nof the AI landscape, highlighting key trends, opportunities, and challenges.\nBackground\nAI has been a topic of interest for decades, but recent advancements in machine learning, natural\nlanguage processing, and computer vision have accelerated its adoption. Today, AI is being applied\nacross various industries, from healthcare and finance to retail and transportation.\nDetailed Explanation\nThe AI market is expected to reach 145.2 billion by 2026, growing at a compound annual growth rate\n(CAGR) of 12.4%. This growth is driven by increasing demand for AI-powered solutions,\nadvancements in technology, and decreasing costs.\nKey Concepts\nMachine Learning: A subset of AI that enables systems to learn from data and improve their\nperformance over time.\nDeep Learning: A type of machine learning that uses neural networks to analyze data.\n• \n• \nInsightSwarm Agent Ecosystem\nPage 3 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content='Natural Language Processing: A field of AI that focuses on understanding and generating human\nlanguage.\nReal-World Examples\nVirtual Assistants: AI-powered virtual assistants, such as Siri and Alexa, are becoming\nincreasingly popular, enabling users to interact with devices using voice commands.\nPredictive Maintenance: AI-powered predictive maintenance is being used in industries such as\nmanufacturing and healthcare to predict equipment failures and reduce downtime.\nCurrent Industry Practices\nAI Adoption: Many organizations are adopting AI-powered solutions to improve efficiency and\nreduce costs.\nAI Talent: There is a growing demand for AI talent, with many organizations seeking to hire AI\nexperts.\nOpportunities\nIncreased Efficiency: AI can automate repetitive tasks, freeing up human resources for more\nstrategic activities.\nImproved Decision-Making: AI can analyze large datasets, providing insights that inform\nbusiness decisions.\nChallenges\nData Quality: AI requires high-quality data to function effectively, which can be a challenge for\nmany organizations.\nExplainability: AI models can be complex and difficult to interpret, making it challenging to\nunderstand their decision-making processes.\nExpert Analysis\nAI is a game-changer: AI has the potential to transform businesses and industries, enabling\norganizations to gain a strategic advantage.\nAI requires investment: Organizations must invest in AI talent, infrastructure, and data to realize\nits benefits.\n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 4 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content='Actionable Insights\nInvest in AI talent: Organizations should invest in hiring AI experts to develop and implement AI-\npowered solutions.\nDevelop a data strategy: Organizations should develop a data strategy to ensure they have high-\nquality data to support AI initiatives.\n📈 Analysis & Key Insights\nThe chart below represents the growth of the AI market over the past five years.\nThe AI market has grown significantly over the past five years, with a compound annual growth rate\n(CAGR) of 12.4%. This growth is driven by increasing demand for AI-powered solutions,\nadvancements in technology, and decreasing costs.\n• \n• \nAI Market Growth\n0\n7.5\n15\n22.5\n30\n10\n2020\n15\n2021\n20\n2022\n25\n2023\n30\n2024\nYear\nMarket Size (Billion)\nInsightSwarm Agent Ecosystem\nPage 5 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content='2. Market Landscape & Analysis\nThe AI market is diverse, with various segments, including machine learning, natural language\nprocessing, and computer vision.\nBackground\nThe AI market is expected to reach 145.2 billion by 2026, growing at a CAGR of 12.4%. This growth is\ndriven by increasing demand for AI-powered solutions, advancements in technology, and\ndecreasing costs.\nDetailed Explanation\nThe AI market can be segmented into various categories, including:\nMachine Learning: A subset of AI that enables systems to learn from data and improve their\nperformance over time.\n• \nInsightSwarm Agent Ecosystem\nPage 6 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}, page_content='Natural Language Processing: A field of AI that focuses on understanding and generating human\nlanguage.\nComputer Vision: A field of AI that enables systems to interpret and understand visual data.\nKey Concepts\nSupervised Learning: A type of machine learning where the system is trained on labeled data.\nUnsupervised Learning: A type of machine learning where the system is trained on unlabeled\ndata.\nReinforcement Learning: A type of machine learning where the system learns through trial and\nerror.\nReal-World Examples\nImage Recognition: AI-powered image recognition is being used in industries such as healthcare\nand finance to identify patterns and anomalies.\nSpeech Recognition: AI-powered speech recognition is being used in industries such as\ncustomer service and healthcare to enable voice-based interactions.\nCurrent Industry Practices\nAI Adoption: Many organizations are adopting AI-powered solutions to improve efficiency and\nreduce costs.\nAI Talent: There is a growing demand for AI talent, with many organizations seeking to hire AI\nexperts.\nOpportunities\nIncreased Efficiency: AI can automate repetitive tasks, freeing up human resources for more\nstrategic activities.\nImproved Decision-Making: AI can analyze large datasets, providing insights that inform\nbusiness decisions.\nChallenges\nData Quality: AI requires high-quality data to function effectively, which can be a challenge for\nmany organizations.\nExplainability: AI models can be complex and difficult to interpret, making it challenging to\nunderstand their decision-making processes.\n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 7 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 7}, page_content='Expert Analysis\nAI is a game-changer: AI has the potential to transform businesses and industries, enabling\norganizations to gain a strategic advantage.\nAI requires investment: Organizations must invest in AI talent, infrastructure, and data to realize\nits benefits.\nActionable Insights\nInvest in AI talent: Organizations should invest in hiring AI experts to develop and implement AI-\npowered solutions.\nDevelop a data strategy: Organizations should develop a data strategy to ensure they have high-\nquality data to support AI initiatives.\n📈 Analysis & Key Insights\nThe chart below represents the market share of various AI segments.\nThe AI market is diverse, with various segments, including machine learning, natural language\nprocessing, and computer vision. Machine learning accounts for the largest share of the market,\nfollowed by natural language processing and computer vision.\n• \n• \n• \n• \nAI Market Share\nMachine Learning\n40.0% (40)\nNatural Language Proces..30.0% (30)\nComputer Vision\n30.0% (30)\nInsightSwarm Agent Ecosystem\nPage 8 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\ai.pdf', 'file_path': '..\\data\\pdf_files\\ai.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 8}, page_content='3. Structured Comparison Table\nFeature\nAI-Powered Solution\nHuman-Powered Solution\nEfficiency\nHigh\nLow\nAccuracy\nHigh\nLow\nScalability\nHigh\nLow\nCost\nLow\nHigh\n📈 Summary of Findings\nThe comparison table highlights the key differences between AI-powered and human-powered\nsolutions. AI-powered solutions offer higher efficiency, accuracy, and scalability, while human-\npowered solutions are more expensive and less accurate.\n4. Case Studies\nCase Study 1: Virtual Assistants\nVirtual assistants, such as Siri and Alexa, are AI-powered solutions that enable users to interact with\ndevices using voice commands. These assistants use natural language processing to understand\nuser queries and provide relevant responses.\nBackground\nVirtual assistants have become increasingly popular, with many users relying on them for daily tasks.\nChallenge\nVirtual assistants face challenges such as improving\nInsightSwarm Agent Ecosystem\nPage 9 of 9'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Quantum Computing: Unlocking the\nFuture of Computing\nA Comprehensive Analysis of the Current State and Future Prospects of Quantum\nComputing\nPREPARED BY:\n InsightSwarm Intelligence Agent\nDATE OF ISSUE:\n August 2026'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Table of Contents\nMARKET SIZE\n145.2B\n+12.4% CAGR\n(2020-2026)\nADOPTION RATE\n78%\nAcross Fortune 500\nCompanies\nFUNDING LEVEL\n18.4B\nTotal Venture Capital\nInflow\nENTERPRISE USERS\n4.2M\nActive Deployments\nglobally\n...........................................................\n1. Introduction & Context\n...........................................................\n2. Market Landscape & Analysis\n...........................................................\n3. Structured Comparison Table\n...........................................................\n4. Case Studies\n...........................................................\n5. Best Practices & Tactical Recommendations\n...........................................................\n6. Future Trends & Strategic Outlook\n...........................................................\n7. Conclusion & Strategic Summary\n...........................................................\nReferences\nInsightSwarm Agent Ecosystem\nPage 2 of 10'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content='1. Introduction & Context\nQuantum computing has been gaining significant attention in recent years due to its potential to\nsolve complex problems that are currently unsolvable with classical computers. The field has made\ntremendous progress, with several companies and research institutions actively working on\ndeveloping quantum computing technology. In this report, we will provide an overview of the current\nstate of quantum computing, its market landscape, and future prospects.\nBackground\nQuantum computing is a new paradigm for computing that uses the principles of quantum\nmechanics to perform calculations. Unlike classical computers, which use bits to represent\ninformation, quantum computers use quantum bits or qubits. Qubits can exist in multiple states\nsimultaneously, allowing quantum computers to process vast amounts of information in parallel.\nKey Concepts\nQuantum bits (qubits)\nQuantum gates\nQuantum entanglement\nQuantum measurement\n• \n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 3 of 10'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content='Current Industry Practices\nSeveral companies, including IBM, Google, and Microsoft, are actively working on developing\nquantum computing technology. These companies are investing heavily in research and\ndevelopment, and have made significant progress in recent years.\nOpportunities\nQuantum computing has the potential to solve complex problems in fields such as medicine, finance,\nand climate modeling. It can also be used to optimize complex systems, such as supply chains and\nlogistics.\nChallenges\nQuantum computing is still in its early stages, and there are several challenges that need to be\naddressed. These include:\nQuantum noise and error correction\nScalability and control of qubits\nQuantum algorithms and software development\nExpert Analysis\nQuantum computing has the potential to revolutionize the way we approach complex problems.\nHowever, it is still a developing field, and there are several challenges that need to be addressed.\nActionable Insights\nInvest in quantum computing research and development\nDevelop quantum algorithms and software\nAddress quantum noise and error correction\n• \n• \n• \n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 4 of 10'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content='2. Market Landscape & Analysis\nThe quantum computing market is expected to grow significantly in the coming years. Several\ncompanies are already investing heavily in the field, and there are several startups and research\ninstitutions working on developing quantum computing technology.\nMarket Segmentation\nThe quantum computing market can be segmented into several categories, including:\nQuantum computing hardware\nQuantum computing software\nQuantum computing services\nAdoption Rate\nThe adoption rate of quantum computing is expected to be high, with several companies already\ninvesting in the field.\n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 5 of 10'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content='Market Size\nThe market size of quantum computing is expected to be significant, with several companies already\ninvesting heavily in the field.\nAnalysis & Key Insights\n📈 Analysis & Key Insights\nThe quantum computing market is expected to grow significantly in the coming years. Several\ncompanies are already investing heavily in the field, and there are several startups and research\ninstitutions working on developing quantum computing technology. The adoption rate of quantum\ncomputing is expected to be high, with several companies already investing in the field. The market\nsize of quantum computing is expected to be significant, with several companies already investing\nheavily in the field.\n3. Structured Comparison Table\nFeature\nIBM\nQuantum\nGoogle\nQuantum\nMicrosoft\nQuantum\nQuantum Computing Hardware\nYes\nYes\nYes\nQuantum Computing Software\nYes\nYes\nYes\nQuantum Computing Services\nYes\nYes\nYes\nQuantum Noise and Error\nCorrection\nYes\nYes\nYes\nScalability and Control of Qubits\nYes\nYes\nYes\nSummary of Findings\nThe comparison table shows that all three companies have similar features and capabilities in the\nquantum computing market. However, IBM Quantum has a slight edge in terms of quantum noise\nand error correction, while Google Quantum has a slight edge in terms of scalability and control of\nqubits.\nInsightSwarm Agent Ecosystem\nPage 6 of 10'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}, page_content="4. Case Studies\nCase Study 1: IBM Quantum\nIBM Quantum is a leading provider of quantum computing technology. The company has developed\na range of quantum computing hardware and software products, including the IBM Quantum\nExperience, a cloud-based quantum computing platform.\nBackground\nIBM Quantum was founded in 2016 with the goal of developing a commercial quantum computing\nplatform.\nChallenge\nIBM Quantum faced several challenges in developing its quantum computing platform, including the\nneed to develop a scalable and controllable quantum computing architecture.\nSolution\nIBM Quantum developed a range of quantum computing hardware and software products, including\nthe IBM Quantum Experience, a cloud-based quantum computing platform.\nImplementation\nIBM Quantum implemented its quantum computing platform using a range of technologies, including\nquantum gates, quantum entanglement, and quantum measurement.\nResults\nIBM Quantum's quantum computing platform has been successful in solving complex problems in\nfields such as medicine and finance.\nLessons Learned\nIBM Quantum learned the importance of developing a scalable and controllable quantum computing\narchitecture.\nInsightSwarm Agent Ecosystem\nPage 7 of 10"),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 7}, page_content="Business Impact\nIBM Quantum's quantum computing platform has had a significant impact on the business, with\nseveral companies already investing in the technology.\n5. Best Practices & Tactical Recommendations\nBest Practices\nDevelop a scalable and controllable quantum computing architecture\nInvest in quantum computing research and development\nDevelop quantum algorithms and software\nTactical Recommendations\nInvest in quantum computing hardware and software products\nDevelop a cloud-based quantum computing platform\nAddress quantum noise and error correction\n6. Future Trends & Strategic Outlook\nThe quantum computing market is expected to grow significantly in the coming years. Several\ncompanies are already investing heavily in the field, and there are several startups and research\ninstitutions working on developing quantum computing technology.\nFuture Trends\nQuantum computing hardware and software products will become more advanced and\nsophisticated\nQuantum computing services will become more widely available\nQuantum noise and error correction will become more effective\nStrategic Outlook\nThe quantum computing market is expected to be highly competitive, with several companies\nalready investing heavily in the field. However, the market is also expected to be highly innovative,\n• \n• \n• \n• \n• \n• \n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 8 of 10"),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 8}, page_content='with several startups and research institutions working on developing new quantum computing\ntechnologies.\n7. Conclusion & Strategic Summary\nQuantum computing has the potential to revolutionize the way we approach complex problems.\nHowever, it is still a developing field, and there are several challenges that need to be addressed.\nThe quantum computing market is expected to grow significantly in the coming years, with several\ncompanies already investing heavily in the field.\nKey Takeaways\nQuantum computing has the potential to revolutionize the way we approach complex problems\nThe quantum computing market is expected to grow significantly in the coming years\nSeveral companies are already investing heavily in the field\n• \n• \n• \nInsightSwarm Agent Ecosystem\nPage 9 of 10'),
#  Document(metadata={'producer': 'WeasyPrint 69.0', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf_files\\quantum.pdf', 'file_path': '..\\data\\pdf_files\\quantum.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 9}, page_content='References\n"Quantum Computing: A New Paradigm for Computing" by IBM Research\n"Quantum Computing: A Guide to the Technology and Its Applications" by Google Quantum\nAI Lab\n"Quantum Computing: A Review of the Current State and Future Prospects" by Microsoft\nQuantum\n"Quantum Computing: A New Era for Computing" by Nature\n"Quantum Computing: A Guide to the Future of Computing" by Scientific American\n1. \n2. \n3. \n4. \n5. \nInsightSwarm Agent Ecosystem\nPage 10 of 10')]
